# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd #analysis
import matplotlib.pyplot as plt # graphs
# %matplotlib inline
import seaborn as sns #data visualization
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
training_dataset = pd.read_csv(r"C:\\Users\\DELL\Desktop\Dataset\rossmann-store-sales\train.csv", sep=',', parse_dates = True, index_col = 'Date',
                    dtype={'StateHoliday':str, 'SchoolHoliday':str})
data2 = pd.read_csv(r"C:\\Users\\DELL\Desktop\Dataset\rossmann-store-sales\store.csv") # https://www.kaggle.com/c/rossmann-store-sales/data

# %% [markdown]
# Understanding the dataset

# %%
sns.pairplot(training_dataset, kind="scatter",vars=["Sales","Customers"]) #plotting graphs with different variables

# %%
sns.pairplot(training_dataset, kind="reg",vars=["Promo","Sales"]) #regression line
plt.show()

# %%
sns.pairplot(training_dataset, kind="reg",vars=["Sales","Customers"])
plt.show()

# %%
new_plot = training_dataset[training_dataset.Customers==500].sort_values('Date')
plt.figure(figsize=(15, 5))  
plt.plot(new_plot.Sales.values[:730])

# %%
print("Attributes", training_dataset.shape)
training_dataset.head()

# %%
print("Attributes", data2.shape)
data2.head()

# %% [markdown]
# Feature Selection and merging data

# %%
data2 = data2.drop(['CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear','Promo2SinceWeek',
                     'Promo2SinceYear'], axis=1)

# %%
dataset_all = = pd.merge(training_dataset, datae, how='left', on='Store')
dataset_all.head()
